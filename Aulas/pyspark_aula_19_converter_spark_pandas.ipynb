# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F

spark = (
    SparkSession.builder.appName("pyspark_aula_18_criando_data_frame")
    .config("spark.sql.repl.eagerEval.enabled", True)
    .getOrCreate()
)

# %%
df = spark.read.parquet("./bases/LOGINS.parquet")

# %%
df
# Out:
# +--------------+--------------------+----------+------------------+------+-------------+---------------+------------+--------------------+-------------------+
# |           cpf|               email|     senha|data_de_nascimento|estado|data_cadastro|           ipv4|cor_favorita|           profissao|           telefone|
# +--------------+--------------------+----------+------------------+------+-------------+---------------+------------+--------------------+-------------------+
# |981.507.362-12|pedro-lucas53@gma...|+7^7E%xFBc|        2006-12-18|    RR|   2023-02-26| 99.107.250.210|        Roxo|    Jogador De Golfe|       31 7785-4046|
# |493.705.168-75|rezendeisaac@hotm...|_O_2GRnGOe|        1992-06-17|    GO|   2023-02-16|  197.11.26.213|       Ciano|Atleta De Arremes...|    (031) 0803-6753|
# |398.471.625-73|felipepires@uol.c...|*Aw5EOAvy9|        1921-11-11|    MG|   2023-01-02|   181.90.63.58|        Azul|      Papiloscopista|       11 9674-0553|
# |092.618.354-06|stellamoraes@bol....|mw0AWYAs#s|        2021-06-01|    AC|   2023-01-08|  26.121.127.94|      Marrom|            Aeromoça|+55 (071) 3033 9177|
# |509.427.136-99| wcarvalho@ig.com.br|pGD%!2Pq5X|        1969-10-28|    AP|   2023-02-14|  76.184.52.163|     Laranja|       Fonoaudiólogo|+55 (071) 6272 2468|
# |218.795.460-94|da-conceicaodavi-...|uhBbFxPA&9|        1986-05-19|    MG|   2023-03-07|    192.93.0.24|        Rosa|             Taxista|   +55 84 0652 9691|
# |715.836.940-48| efreitas@bol.com.br|s#q9VZt&xl|        2018-04-20|    MG|   2023-01-13| 76.251.188.148|      Branco|Produtor De Audio...|+55 (084) 1363 0052|
# |475.698.032-56|   wnunes@bol.com.br|_8az1W%n7g|        1996-05-12|    SE|   2023-02-04|139.196.176.154|        Azul|          Cadeirinha|    (071) 1640-3388|
# |217.639.540-99| jribeiro@bol.com.br|MEf1X7fj_0|        2021-10-05|    PA|   2023-03-02|    71.22.224.5|      Marrom|             Geólogo|       21 1432 4092|
# |261.938.750-77|  murilo05@gmail.com|Te&gO7GkKs|        1917-01-05|    MT|   2023-02-21| 136.54.123.165|      Marrom|      Técnico De Som|+55 (084) 5878-3346|
# |520.831.796-68| joaquim57@ig.com.br|&2E1NY+ARc|        1912-05-25|    BA|   2023-01-25| 78.196.255.126|        Rosa|         Esteticista|       41 7914-3753|
# |413.087.526-44|alexiada-rocha@ig...|@f@!Z!2c*2|        1920-05-26|    MS|   2023-02-18|  182.61.65.201|     Laranja|        Microfonista|    (021) 3739-2944|
# |509.287.143-14|   pmendes@gmail.com|M+^XDBfe(2|        1938-03-11|    RR|   2023-01-19|  61.234.208.17| Verde Claro|              Fiscal|+55 (084) 5940-1932|
# |563.170.492-70|  renan46@bol.com.br|Rp%2pVqfe$|        1922-09-01|    PA|   2023-02-01| 122.203.83.177|Verde Escuro|        Contabilista|   +55 41 6248 5773|
# |098.712.346-78|manuelada-rosa@ho...|#hEIEOztQ3|        2013-01-10|    SE|   2023-01-07|  175.18.73.211|     Violeta| Seguidor De Compras|       51 0278 0564|
# |345.709.261-34|    usales@ig.com.br|b_8xaY$ozJ|        1992-10-16|    AM|   2023-01-05|    97.93.29.75|        Rosa|           Almirante|    (084) 8993-4521|
# |318.254.906-51|pereiranicolas@ho...|YA9I85Wb+2|        1945-11-18|    MA|   2023-01-24| 182.195.33.137|     Amarelo|   Consultor De Moda|    (084) 4591 3795|
# |610.287.453-62|cardosolivia@ig.c...|yXkDW7Ebh*|        1915-11-15|    GO|   2023-01-22| 195.194.63.184|     Laranja|            Barbeiro|   +55 61 8967-9563|
# |615.790.842-49|  brenda39@ig.com.br|XS$84Hpsnw|        1964-02-01|    RJ|   2023-02-16|  21.252.226.29|      Branco|  Promotor De Vendas|+55 (021) 4751 2004|
# |624.095.138-24|luizapeixoto@gmai...|TbKy82Kda$|        1959-02-01|    DF|   2023-02-25|  105.107.23.13|       Ciano|    Implantodontista|       84 1293 1906|
# +--------------+--------------------+----------+------------------+------+-------------+---------------+------------+--------------------+-------------------+
# only showing top 20 rows

# %%
type(df)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df.collect()
# Out:
# [Row(cpf='981.507.362-12', email='pedro-lucas53@gmail.com', senha='+7^7E%xFBc', data_de_nascimento=datetime.date(2006, 12, 18), estado='RR', data_cadastro=datetime.date(2023, 2, 26), ipv4='99.107.250.210', cor_favorita='Roxo', profissao='Jogador De Golfe', telefone='31 7785-4046'),
#  Row(cpf='493.705.168-75', email='rezendeisaac@hotmail.com', senha='_O_2GRnGOe', data_de_nascimento=datetime.date(1992, 6, 17), estado='GO', data_cadastro=datetime.date(2023, 2, 16), ipv4='197.11.26.213', cor_favorita='Ciano', profissao='Atleta De Arremesso De Peso', telefone='(031) 0803-6753'),
#  Row(cpf='398.471.625-73', email='felipepires@uol.com.br', senha='*Aw5EOAvy9', data_de_nascimento=datetime.date(1921, 11, 11), estado='MG', data_cadastro=datetime.date(2023, 1, 2), ipv4='181.90.63.58', cor_favorita='Azul', profissao='Papiloscopista', telefone='11 9674-0553'),
#  Row(cpf='092.618.354-06', email='stellamoraes@bol.com.br', senha='mw0AWYAs#s', data_de_nascimento=datetime.date(2021, 6, 1), estado='AC', data_cadastro=datetime.date(2023, 1, 8), ipv4='26.121.127.94', cor_favorita='Marrom', profissao='Aeromoça', telefone='+55 (071) 3033 9177'),
#  Row(cpf='509.427.136-99', email='wcarvalho@ig.com.br', senha='pGD%!2Pq5X', data_de_nascimento=datetime.date(1969, 10, 28), estado='AP', data_cadastro=datetime.date(2023, 2, 14), ipv4='76.184.52.163', cor_favorita='Laranja', profissao='Fonoaudiólogo', telefone='+55 (071) 6272 2468'),
#  Row(cpf='218.795.460-94', email='da-conceicaodavi-lucas@hotmail.com', senha='uhBbFxPA&9', data_de_nascimento=datetime.date(1986, 5, 19), estado='MG', data_cadastro=datetime.date(2023, 3, 7), ipv4='192.93.0.24', cor_favorita='Rosa', profissao='Taxista', telefone='+55 84 0652 9691'),
#  Row(cpf='715.836.940-48', email='efreitas@bol.com.br', senha='s#q9VZt&xl', data_de_nascimento=datetime.date(2018, 4, 20), estado='MG', data_cadastro=datetime.date(2023, 1, 13), ipv4='76.251.188.148', cor_favorita='Branco', profissao='Produtor De Audio Visual', telefone='+55 (084) 1363 0052'),
#  Row(cpf='475.698.032-56', email='wnunes@bol.com.br', senha='_8az1W%n7g', data_de_nascimento=datetime.date(1996, 5, 12), estado='SE', data_cadastro=datetime.date(2023, 2, 4), ipv4='139.196.176.154', cor_favorita='Azul', profissao='Cadeirinha', telefone='(071) 1640-3388'),
#  Row(cpf='217.639.540-99', email='jribeiro@bol.com.br', senha='MEf1X7fj_0', data_de_nascimento=datetime.date(2021, 10, 5), estado='PA', data_cadastro=datetime.date(2023, 3, 2), ipv4='71.22.224.5', cor_favorita='Marrom', profissao='Geólogo', telefone='21 1432 4092'),
#  Row(cpf='261.938.750-77', email='murilo05@gmail.com', senha='Te&gO7GkKs', data_de_nascimento=datetime.date(1917, 1, 5), estado='MT', data_cadastro=datetime.date(2023, 2, 21), ipv4='136.54.123.165', cor_favorita='Marrom', profissao='Técnico De Som', telefone='+55 (084) 5878-3346'),
#  Row(cpf='520.831.796-68', email='joaquim57@ig.com.br', senha='&2E1NY+ARc', data_de_nascimento=datetime.date(1912, 5, 25), estado='BA', data_cadastro=datetime.date(2023, 1, 25), ipv4='78.196.255.126', cor_favorita='Rosa', profissao='Esteticista', telefone='41 7914-3753'),
#  Row(cpf='413.087.526-44', email='alexiada-rocha@ig.com.br', senha='@f@!Z!2c*2', data_de_nascimento=datetime.date(1920, 5, 26), estado='MS', data_cadastro=datetime.date(2023, 2, 18), ipv4='182.61.65.201', cor_favorita='Laranja', profissao='Microfonista', telefone='(021) 3739-2944'),
#  Row(cpf='509.287.143-14', email='pmendes@gmail.com', senha='M+^XDBfe(2', data_de_nascimento=datetime.date(1938, 3, 11), estado='RR', data_cadastro=datetime.date(2023, 1, 19), ipv4='61.234.208.17', cor_favorita='Verde Claro', profissao='Fiscal', telefone='+55 (084) 5940-1932'),
#  Row(cpf='563.170.492-70', email='renan46@bol.com.br', senha='Rp%2pVqfe$', data_de_nascimento=datetime.date(1922, 9, 1), estado='PA', data_cadastro=datetime.date(2023, 2, 1), ipv4='122.203.83.177', cor_favorita='Verde Escuro', profissao='Contabilista', telefone='+55 41 6248 5773'),
#  Row(cpf='098.712.346-78', email='manuelada-rosa@hotmail.com', senha='#hEIEOztQ3', data_de_nascimento=datetime.date(2013, 1, 10), estado='SE', data_cadastro=datetime.date(2023, 1, 7), ipv4='175.18.73.211', cor_favorita='Violeta', profissao='Seguidor De Compras', telefone='51 0278 0564'),
#  Row(cpf='345.709.261-34', email='usales@ig.com.br', senha='b_8xaY$ozJ', data_de_nascimento=datetime.date(1992, 10, 16), estado='AM', data_cadastro=datetime.date(2023, 1, 5), ipv4='97.93.29.75', cor_favorita='Rosa', profissao='Almirante', telefone='(084) 8993-4521'),
#  Row(cpf='318.254.906-51', email='pereiranicolas@hotmail.com', senha='YA9I85Wb+2', data_de_nascimento=datetime.date(1945, 11, 18), estado='MA', data_cadastro=datetime.date(2023, 1, 24), ipv4='182.195.33.137', cor_favorita='Amarelo', profissao='Consultor De Moda', telefone='(084) 4591 3795'),
#  Row(cpf='610.287.453-62', email='cardosolivia@ig.com.br', senha='yXkDW7Ebh*', data_de_nascimento=datetime.date(1915, 11, 15), estado='GO', data_cadastro=datetime.date(2023, 1, 22), ipv4='195.194.63.184', cor_favorita='Laranja', profissao='Barbeiro', telefone='+55 61 8967-9563'),
#  Row(cpf='615.790.842-49', email='brenda39@ig.com.br', senha='XS$84Hpsnw', data_de_nascimento=datetime.date(1964, 2, 1), estado='RJ', data_cadastro=datetime.date(2023, 2, 16), ipv4='21.252.226.29', cor_favorita='Branco', profissao='Promotor De Vendas', telefone='+55 (021) 4751 2004'),
#  Row(cpf='624.095.138-24', email='luizapeixoto@gmail.com', senha='TbKy82Kda$', data_de_nascimento=datetime.date(1959, 2, 1), estado='DF', data_cadastro=datetime.date(2023, 2, 25), ipv4='105.107.23.13', cor_favorita='Ciano', profissao='Implantodontista', telefone='84 1293 1906'),
#  Row(cpf='027.548.639-74', email='msilveira@hotmail.com', senha='*JGkXTxw20', data_de_nascimento=datetime.date(2006, 10, 21), estado='RS', data_cadastro=datetime.date(2023, 3, 15), ipv4='28.79.103.46', cor_favorita='Marrom', profissao='Transcritor', telefone='+55 41 4492 4068'),
#  Row(cpf='786.132.594-64', email='vinicius86@yahoo.com.br', senha=')0UFwLnQeY', data_de_nascimento=datetime.date(1935, 7, 29), estado='MA', data_cadastro=datetime.date(2023, 2, 25), ipv4='142.49.53.78', cor_favorita='Amarelo', profissao='Geólogo', telefone='+55 41 8499 1550'),
#  Row(cpf='957.184.360-10', email='thomas46@hotmail.com', senha='(nHUASneS4', data_de_nascimento=datetime.date(1993, 3, 13), estado='CE', data_cadastro=datetime.date(2023, 2, 25), ipv4='192.177.35.142', cor_favorita='Roxo', profissao='Judoca', telefone='(084) 3806-6915'),
#  Row(cpf='573.619.804-57', email='hnogueira@ig.com.br', senha='&9Ejtll$PF', data_de_nascimento=datetime.date(1949, 3, 6), estado='SP', data_cadastro=datetime.date(2023, 1, 27), ipv4='168.162.247.252', cor_favorita='Cinza', profissao='Instalador De Linha Telefônica', telefone='(031) 9148 3933'),
#  Row(cpf='170.965.428-76', email='qdias@gmail.com', senha='6z5AgU_##v', data_de_nascimento=datetime.date(1995, 8, 17), estado='GO', data_cadastro=datetime.date(2023, 2, 2), ipv4='197.248.140.141', cor_favorita='Verde', profissao='Auditor', telefone='84 9168 0488'),
#  Row(cpf='075.291.346-80', email='rgoncalves@hotmail.com', senha='!ZL!yIcdt2', data_de_nascimento=datetime.date(1994, 2, 18), estado='SC', data_cadastro=datetime.date(2023, 3, 4), ipv4='118.244.5.155', cor_favorita='Cinza', profissao='Instalador De Linha Telefônica', telefone='(021) 0787 3744'),
#  Row(cpf='348.215.690-51', email='omoreira@bol.com.br', senha='!8maDkdVnY', data_de_nascimento=datetime.date(2008, 10, 24), estado='MG', data_cadastro=datetime.date(2023, 2, 20), ipv4='177.2.242.176', cor_favorita='Verde Escuro', profissao='Adestrador De Animais', telefone='+55 61 3217-9930'),
#  Row(cpf='875.130.249-79', email='da-rocharebeca@hotmail.com', senha='FlOoH0I6)6', data_de_nascimento=datetime.date(1972, 10, 5), estado='PE', data_cadastro=datetime.date(2023, 2, 11), ipv4='126.171.28.31', cor_favorita='Violeta', profissao='Modelista', telefone='+55 84 1130-9822'),
#  Row(cpf='439.107.528-88', email='costagabriel@gmail.com', senha='^+kLpbkVw2', data_de_nascimento=datetime.date(1960, 1, 5), estado='DF', data_cadastro=datetime.date(2023, 2, 5), ipv4='122.151.20.128', cor_favorita='Amarelo', profissao='Neurocirurgião', telefone='+55 61 4028-1911'),
#  Row(cpf='498.071.356-48', email='davi47@bol.com.br', senha='$XJ)MDIUj7', data_de_nascimento=datetime.date(1985, 8, 25), estado='MA', data_cadastro=datetime.date(2023, 3, 10), ipv4='211.146.130.224', cor_favorita='Azul', profissao='Lenhador', telefone='0800 449 6212'),
#  Row(cpf='740.925.183-23', email='leandrodas-neves@hotmail.com', senha='_0EL5chQXe', data_de_nascimento=datetime.date(2012, 4, 15), estado='BA', data_cadastro=datetime.date(2023, 1, 14), ipv4='52.7.88.35', cor_favorita='Azul Escuro', profissao='Jogador De Hóquei', telefone='61 3040-6271'),
#  Row(cpf='807.695.421-58', email='joao-guilhermeda-rocha@uol.com.br', senha='Z^9Og04O*(', data_de_nascimento=datetime.date(2008, 11, 4), estado='GO', data_cadastro=datetime.date(2023, 1, 6), ipv4='45.56.63.111', cor_favorita='Roxo', profissao='Promotor De Eventos', telefone='+55 81 9388-4795'),
#  Row(cpf='247.538.610-07', email='brunacastro@gmail.com', senha='&%llJSSz6l', data_de_nascimento=datetime.date(2005, 5, 10), estado='RO', data_cadastro=datetime.date(2023, 1, 21), ipv4='196.68.36.53', cor_favorita='Marrom', profissao='Consultor De Moda', telefone='(011) 4483 4953'),
#  Row(cpf='534.921.708-97', email='luigirodrigues@ig.com.br', senha='o^7iKswgB)', data_de_nascimento=datetime.date(1919, 12, 8), estado='BA', data_cadastro=datetime.date(2023, 1, 17), ipv4='153.175.239.154', cor_favorita='Marrom', profissao='Consultor De Radiestesia', telefone='+55 31 0462 8967'),
#  Row(cpf='738.095.461-00', email='gustavo-henrique35@yahoo.com.br', senha='u9cYIezj(P', data_de_nascimento=datetime.date(1958, 12, 2), estado='RO', data_cadastro=datetime.date(2023, 3, 8), ipv4='30.230.142.99', cor_favorita='Cinza', profissao='Profissional De Logística', telefone='+55 (081) 1846-1047'),
#  Row(cpf='734.801.926-96', email='pedro-miguel43@bol.com.br', senha='*72CCJdxX0', data_de_nascimento=datetime.date(1965, 9, 14), estado='SP', data_cadastro=datetime.date(2023, 2, 22), ipv4='222.145.189.67', cor_favorita='Roxo', profissao='Coach', telefone='51 9026 3441'),
#  Row(cpf='427.093.568-56', email='luiz-gustavofernandes@yahoo.com.br', senha='a+Z5#HgFkm', data_de_nascimento=datetime.date(1987, 8, 26), estado='MS', data_cadastro=datetime.date(2023, 2, 6), ipv4='107.189.80.120', cor_favorita='Verde Escuro', profissao='Técnico Em Documentação', telefone='71 1401-9745'),
#  Row(cpf='524.789.301-88', email='diogosales@yahoo.com.br', senha='*yWPtYdi71', data_de_nascimento=datetime.date(1931, 1, 17), estado='PR', data_cadastro=datetime.date(2023, 1, 14), ipv4='149.106.171.164', cor_favorita='Marrom', profissao='Turismólogo', telefone='+55 (041) 6393-0208'),
#  Row(cpf='529.803.746-10', email='luigifreitas@yahoo.com.br', senha='KV^16Iye@D', data_de_nascimento=datetime.date(1934, 11, 28), estado='AP', data_cadastro=datetime.date(2023, 2, 20), ipv4='215.34.116.170', cor_favorita='Marrom', profissao='Ombudsman', telefone='+55 84 2689-7797'),
#  Row(cpf='615.743.802-90', email='cardosoisabella@hotmail.com', senha='t0xW7aZJ_3', data_de_nascimento=datetime.date(1999, 12, 21), estado='MS', data_cadastro=datetime.date(2023, 1, 8), ipv4='33.60.110.202', cor_favorita='Laranja', profissao='Acompanhante', telefone='+55 71 5619 9136'),
#  Row(cpf='451.382.670-35', email='barrosalice@uol.com.br', senha='Rvr48wZi)g', data_de_nascimento=datetime.date(2016, 6, 9), estado='MS', data_cadastro=datetime.date(2023, 2, 4), ipv4='20.156.31.172', cor_favorita='Verde Claro', profissao='Diagramador', telefone='61 6933 9326'),
#  Row(cpf='486.970.253-38', email='isabelly04@uol.com.br', senha='9n8Gsa#7&*', data_de_nascimento=datetime.date(1934, 11, 26), estado='AM', data_cadastro=datetime.date(2023, 3, 3), ipv4='30.212.117.133', cor_favorita='Ciano', profissao='Triatleta', telefone='+55 51 5926 5593'),
#  Row(cpf='047.528.369-47', email='almeidaevelyn@gmail.com', senha='@8JmQG4t@x', data_de_nascimento=datetime.date(1980, 11, 13), estado='AL', data_cadastro=datetime.date(2023, 2, 15), ipv4='92.65.10.245', cor_favorita='Marrom', profissao='Paisagista', telefone='+55 (084) 8760-9088'),
#  Row(cpf='417.902.385-79', email='vda-cruz@bol.com.br', senha='g8NiwxWC_z', data_de_nascimento=datetime.date(1994, 5, 11), estado='AC', data_cadastro=datetime.date(2023, 2, 7), ipv4='146.83.148.200', cor_favorita='Ciano', profissao='Profissional De Informática', telefone='+55 (071) 9845-9087'),
#  Row(cpf='089.462.357-56', email='vitoria83@ig.com.br', senha='(8gXQeIeA3', data_de_nascimento=datetime.date(2014, 11, 18), estado='AL', data_cadastro=datetime.date(2023, 2, 24), ipv4='182.161.33.191', cor_favorita='Marrom', profissao='Oculista', telefone='+55 (084) 8655 2371'),
#  Row(cpf='607.291.534-52', email='maria-julia70@bol.com.br', senha='@(fO&ei%1e', data_de_nascimento=datetime.date(1953, 8, 28), estado='GO', data_cadastro=datetime.date(2023, 1, 10), ipv4='10.121.107.117', cor_favorita='Azul Escuro', profissao='Técnico Em Rede', telefone='(031) 3689 5367'),
#  Row(cpf='238.594.160-06', email='uduarte@bol.com.br', senha='h$2W8we*ZU', data_de_nascimento=datetime.date(1982, 3, 24), estado='ES', data_cadastro=datetime.date(2023, 1, 22), ipv4='214.223.195.14', cor_favorita='Ciano', profissao='Espeleologista', telefone='+55 41 5206-4691'),
#  Row(cpf='472.169.308-78', email='fnascimento@gmail.com', senha='tg4*MbRT%)', data_de_nascimento=datetime.date(1916, 10, 13), estado='SE', data_cadastro=datetime.date(2023, 1, 26), ipv4='170.27.50.118', cor_favorita='Azul', profissao='Panificador/Padeiro', telefone='+55 81 3465 6714'),
#  Row(cpf='534.092.768-74', email='hda-mota@bol.com.br', senha='pKxoK&k#_1', data_de_nascimento=datetime.date(2005, 5, 30), estado='ES', data_cadastro=datetime.date(2023, 1, 11), ipv4='102.210.186.93', cor_favorita='Branco', profissao='Administrador De Banco De Dados Dba', telefone='(084) 8912 3569'),
#  Row(cpf='210.549.367-06', email='ana23@uol.com.br', senha='&#6ZAkAKWh', data_de_nascimento=datetime.date(1958, 4, 6), estado='AC', data_cadastro=datetime.date(2023, 3, 9), ipv4='38.117.200.190', cor_favorita='Verde', profissao='Kite-Surfer', telefone='(011) 2149 3857'),
#  Row(cpf='635.021.978-30', email='ufernandes@ig.com.br', senha='TYI0X7)eh@', data_de_nascimento=datetime.date(1991, 5, 17), estado='MS', data_cadastro=datetime.date(2023, 3, 6), ipv4='72.43.200.207', cor_favorita='Magenta', profissao='Balconista', telefone='+55 21 0766-4829'),
#  Row(cpf='869.072.315-30', email='luiz-gustavorocha@gmail.com', senha='$62UN05c(9', data_de_nascimento=datetime.date(1980, 10, 19), estado='SP', data_cadastro=datetime.date(2023, 1, 4), ipv4='53.167.75.100', cor_favorita='Verde Claro', profissao='Lactarista Hospitalar', telefone='+55 31 1296 8466'),
#  Row(cpf='708.921.356-03', email='caue33@gmail.com', senha='C!Zu4AqeTa', data_de_nascimento=datetime.date(2002, 5, 20), estado='SE', data_cadastro=datetime.date(2023, 1, 14), ipv4='216.171.161.198', cor_favorita='Verde', profissao='Pedicure', telefone='0800 486 6096'),
#  Row(cpf='384.716.209-87', email='talmeida@hotmail.com', senha='k8IP9(Kz_v', data_de_nascimento=datetime.date(1955, 4, 23), estado='RJ', data_cadastro=datetime.date(2023, 3, 6), ipv4='120.159.158.101', cor_favorita='Violeta', profissao='Catador De Material Reciclável', telefone='+55 (051) 5573 2964'),
#  Row(cpf='875.041.326-08', email='ifarias@gmail.com', senha='+0R9Bbvn)5', data_de_nascimento=datetime.date(1957, 8, 5), estado='SC', data_cadastro=datetime.date(2023, 2, 25), ipv4='93.177.145.160', cor_favorita='Roxo', profissao='Político', telefone='(061) 6603-1355'),
#  Row(cpf='164.593.782-82', email='joao64@gmail.com', senha='p8HSoDMn&n', data_de_nascimento=datetime.date(1950, 3, 20), estado='AP', data_cadastro=datetime.date(2023, 2, 13), ipv4='209.64.45.64', cor_favorita='Verde Escuro', profissao='Regente', telefone='+55 (081) 8127 1919'),
#  Row(cpf='308.942.751-60', email='hpires@gmail.com', senha='#^yq9HIt0h', data_de_nascimento=datetime.date(1996, 3, 8), estado='PE', data_cadastro=datetime.date(2023, 2, 14), ipv4='139.209.144.207', cor_favorita='Ciano', profissao='Estofador', telefone='+55 31 1784 8068'),
#  Row(cpf='208.367.915-68', email='brendacaldeira@yahoo.com.br', senha='cXn0ARuB(O', data_de_nascimento=datetime.date(1967, 9, 24), estado='TO', data_cadastro=datetime.date(2023, 1, 10), ipv4='207.26.140.226', cor_favorita='Amarelo', profissao='Líder Comunitário', telefone='+55 84 8553 5334'),
#  Row(cpf='149.857.260-01', email='mda-costa@hotmail.com', senha='4hf6EYFb$m', data_de_nascimento=datetime.date(2005, 8, 7), estado='AL', data_cadastro=datetime.date(2023, 1, 8), ipv4='101.34.19.246', cor_favorita='Rosa', profissao='Gagsman', telefone='0800 183 2070'),
#  Row(cpf='230.564.718-26', email='tfarias@gmail.com', senha='6jCS$bd!*o', data_de_nascimento=datetime.date(1987, 12, 13), estado='MS', data_cadastro=datetime.date(2023, 1, 26), ipv4='66.199.192.253', cor_favorita='Verde Claro', profissao='Assistente Administrativo', telefone='51 8442 4126'),
#  Row(cpf='376.198.054-00', email='theo46@yahoo.com.br', senha='_WNmFcrq43', data_de_nascimento=datetime.date(1972, 12, 14), estado='RO', data_cadastro=datetime.date(2023, 2, 8), ipv4='164.43.203.136', cor_favorita='Rosa', profissao='Engenheiro De Petróleo', telefone='+55 (011) 2401-9634'),
#  Row(cpf='275.638.901-30', email='heloisa87@gmail.com', senha='&5t9Ip*bE$', data_de_nascimento=datetime.date(1958, 12, 8), estado='AC', data_cadastro=datetime.date(2023, 2, 23), ipv4='165.151.118.25', cor_favorita='Roxo', profissao='Cineasta', telefone='+55 (084) 7162 3094'),
#  Row(cpf='291.358.407-14', email='lavinia54@ig.com.br', senha='NyI@+8Kd!1', data_de_nascimento=datetime.date(1982, 1, 28), estado='SP', data_cadastro=datetime.date(2023, 2, 26), ipv4='79.132.46.55', cor_favorita='Preto', profissao='Profissional De Relacionamento Com Investidores Ri', telefone='+55 51 5526 8284'),
#  Row(cpf='479.305.682-29', email='ebarros@bol.com.br', senha='@RJR#F9i40', data_de_nascimento=datetime.date(2022, 11, 28), estado='RO', data_cadastro=datetime.date(2023, 2, 5), ipv4='25.193.96.93', cor_favorita='Azul', profissao='Esteticista', telefone='51 8923 1493'),
#  Row(cpf='460.125.983-51', email='lazevedo@gmail.com', senha='uC0O7QdE&B', data_de_nascimento=datetime.date(1972, 7, 14), estado='SP', data_cadastro=datetime.date(2023, 1, 24), ipv4='221.155.104.128', cor_favorita='Preto', profissao='Atleta De Arremesso De Peso', telefone='+55 71 9251-1645'),
#  Row(cpf='492.568.703-47', email='ksouza@bol.com.br', senha='+)az^0NfXB', data_de_nascimento=datetime.date(1976, 9, 11), estado='AL', data_cadastro=datetime.date(2023, 2, 14), ipv4='50.116.252.134', cor_favorita='Azul Escuro', profissao='Contramestre Em Transporte Marítimo', telefone='(081) 7077 2234'),
#  Row(cpf='759.821.346-19', email='gabriela70@ig.com.br', senha='Qf0$MCOwC#', data_de_nascimento=datetime.date(1984, 11, 26), estado='MS', data_cadastro=datetime.date(2023, 2, 28), ipv4='65.132.234.55', cor_favorita='Branco', profissao='Ferramenteiro', telefone='61 9917 4458'),
#  Row(cpf='310.957.682-12', email='barrosalana@bol.com.br', senha='+4La8ExOB(', data_de_nascimento=datetime.date(2007, 1, 27), estado='RS', data_cadastro=datetime.date(2023, 3, 8), ipv4='162.65.28.12', cor_favorita='Rosa', profissao='Juiz De Direito', telefone='84 8789-5492'),
#  Row(cpf='859.730.624-65', email='jesusjoao-pedro@bol.com.br', senha='e6GTOgSu&x', data_de_nascimento=datetime.date(1934, 12, 10), estado='RS', data_cadastro=datetime.date(2023, 3, 14), ipv4='166.167.217.88', cor_favorita='Azul', profissao='Especialista Em Agronegócios', telefone='(061) 5783-0665'),
#  Row(cpf='876.534.029-92', email='pietrarocha@hotmail.com', senha='YqG8G82#M(', data_de_nascimento=datetime.date(2018, 9, 20), estado='BA', data_cadastro=datetime.date(2023, 2, 7), ipv4='7.65.90.115', cor_favorita='Azul', profissao='General', telefone='81 2134-1812'),
#  Row(cpf='023.965.814-06', email='daniela34@ig.com.br', senha='a6erVAf%)9', data_de_nascimento=datetime.date(1924, 10, 14), estado='PB', data_cadastro=datetime.date(2023, 1, 3), ipv4='204.207.148.123', cor_favorita='Amarelo', profissao='Ortodontista', telefone='+55 31 5756 9535'),
#  Row(cpf='967.253.814-64', email='ana-juliasantos@hotmail.com', senha=')m6l4Zq$F%', data_de_nascimento=datetime.date(1957, 11, 25), estado='RS', data_cadastro=datetime.date(2023, 3, 4), ipv4='217.234.151.70', cor_favorita='Verde', profissao='Juiz Ou Árbitro De Futebol', telefone='+55 (021) 4758-1330'),
#  Row(cpf='567.918.340-48', email='gmoreira@gmail.com', senha='0!017S0ZLy', data_de_nascimento=datetime.date(1979, 1, 29), estado='RO', data_cadastro=datetime.date(2023, 3, 11), ipv4='168.232.170.74', cor_favorita='Verde Escuro', profissao='Moldador', telefone='(011) 1909 0174'),
#  Row(cpf='047.685.321-44', email='jesusana-clara@yahoo.com.br', senha='nD^64ECzr!', data_de_nascimento=datetime.date(1932, 2, 26), estado='CE', data_cadastro=datetime.date(2023, 3, 12), ipv4='69.45.133.68', cor_favorita='Magenta', profissao='Digitador', telefone='0300 388 5045'),
#  Row(cpf='387.940.612-03', email='renanda-rocha@ig.com.br', senha='J@7g(ZC2Za', data_de_nascimento=datetime.date(2016, 4, 7), estado='BA', data_cadastro=datetime.date(2023, 3, 3), ipv4='161.182.89.54', cor_favorita='Azul', profissao='Windsurfer', telefone='11 7835-0713'),
#  Row(cpf='673.504.918-75', email='da-motaisabelly@gmail.com', senha='&#1p4%Gqfz', data_de_nascimento=datetime.date(2003, 2, 25), estado='RS', data_cadastro=datetime.date(2023, 1, 30), ipv4='141.112.137.141', cor_favorita='Azul', profissao='Intérprete', telefone='+55 (011) 2871 0453'),
#  Row(cpf='749.013.682-22', email='julia43@uol.com.br', senha='ff0BTHFv(B', data_de_nascimento=datetime.date(2018, 11, 25), estado='MS', data_cadastro=datetime.date(2023, 2, 5), ipv4='84.161.109.147', cor_favorita='Verde Claro', profissao='Revendedor', telefone='(041) 2295 9010'),
#  Row(cpf='837.410.256-07', email='martinsmaysa@bol.com.br', senha='(Z8RNs%un6', data_de_nascimento=datetime.date(1972, 8, 21), estado='SP', data_cadastro=datetime.date(2023, 2, 24), ipv4='157.119.230.252', cor_favorita='Cinza', profissao='Laboratorista', telefone='+55 (084) 4945-6200'),
#  Row(cpf='041.237.869-87', email='dcampos@bol.com.br', senha='$v0JLNYa#1', data_de_nascimento=datetime.date(1968, 3, 29), estado='GO', data_cadastro=datetime.date(2023, 3, 11), ipv4='71.231.219.114', cor_favorita='Azul Escuro', profissao='Gerente De Vendas', telefone='(041) 4975-8677'),
#  Row(cpf='371.849.256-37', email='bsouza@ig.com.br', senha='y8JpBdaD#)', data_de_nascimento=datetime.date(1978, 4, 13), estado='GO', data_cadastro=datetime.date(2023, 2, 11), ipv4='47.173.23.135', cor_favorita='Marrom', profissao='Mecânico', telefone='+55 61 0987 5226'),
#  Row(cpf='907.154.268-85', email='bryancampos@ig.com.br', senha='iji*Bp0m(1', data_de_nascimento=datetime.date(1909, 9, 29), estado='RR', data_cadastro=datetime.date(2023, 1, 23), ipv4='78.243.210.49', cor_favorita='Magenta', profissao='Gastrônomo', telefone='+55 (021) 3837 9360'),
#  Row(cpf='392.751.804-23', email='maria-sophiada-luz@yahoo.com.br', senha='ti+4bIy1RI', data_de_nascimento=datetime.date(2009, 2, 5), estado='SC', data_cadastro=datetime.date(2023, 1, 26), ipv4='169.43.129.50', cor_favorita='Branco', profissao='Vistoriador De Sinistros', telefone='+55 (084) 2025-2795'),
#  Row(cpf='379.108.624-31', email='ana60@hotmail.com', senha='_9(_qvZj9*', data_de_nascimento=datetime.date(1916, 12, 24), estado='MT', data_cadastro=datetime.date(2023, 2, 19), ipv4='35.183.200.59', cor_favorita='Verde Escuro', profissao='Ciclista', telefone='(031) 1774-1308'),
#  Row(cpf='305.796.218-12', email='mendesmanuela@bol.com.br', senha='f4YS#RS8@5', data_de_nascimento=datetime.date(1926, 4, 24), estado='RN', data_cadastro=datetime.date(2023, 1, 23), ipv4='71.167.226.45', cor_favorita='Preto', profissao='Florista', telefone='+55 41 6396-4347'),
#  Row(cpf='730.184.526-07', email='fviana@ig.com.br', senha='1(3oLDln$8', data_de_nascimento=datetime.date(1938, 10, 23), estado='SP', data_cadastro=datetime.date(2023, 3, 2), ipv4='99.31.171.138', cor_favorita='Verde Escuro', profissao='Profissional De Informática', telefone='0900-429-5628'),
#  Row(cpf='931.762.580-03', email='rocharafaela@yahoo.com.br', senha='Su9&Ik2p+3', data_de_nascimento=datetime.date(1919, 10, 14), estado='RN', data_cadastro=datetime.date(2023, 2, 21), ipv4='5.199.85.40', cor_favorita='Cinza', profissao='Chaveiro', telefone='(011) 6123-1518'),
#  Row(cpf='739.628.014-13', email='iaraujo@uol.com.br', senha='DX+C7FQw*d', data_de_nascimento=datetime.date(1991, 3, 5), estado='PE', data_cadastro=datetime.date(2023, 3, 2), ipv4='12.226.164.38', cor_favorita='Roxo', profissao='Retificador', telefone='51 6855 2871'),
#  Row(cpf='248.376.051-17', email='dmoura@hotmail.com', senha='k7&TpiJa%b', data_de_nascimento=datetime.date(2022, 9, 1), estado='RJ', data_cadastro=datetime.date(2023, 2, 25), ipv4='84.59.19.142', cor_favorita='Branco', profissao='Jogador De Handebol', telefone='+55 (021) 3753-6334'),
#  Row(cpf='015.289.376-86', email='xcardoso@hotmail.com', senha='2oNEEO5G(H', data_de_nascimento=datetime.date(1916, 9, 11), estado='SC', data_cadastro=datetime.date(2023, 2, 7), ipv4='78.128.223.183', cor_favorita='Azul', profissao='Químico Farmacêutico', telefone='+55 (021) 5075-4981'),
#  Row(cpf='542.719.036-80', email='maria-luiza65@uol.com.br', senha='3)Uv_W0j(!', data_de_nascimento=datetime.date(1982, 7, 26), estado='RJ', data_cadastro=datetime.date(2023, 1, 18), ipv4='187.98.240.67', cor_favorita='Rosa', profissao='Diplomata', telefone='+55 (021) 7739-9396'),
#  Row(cpf='569.327.418-73', email='caio32@uol.com.br', senha='@(LSxkPz90', data_de_nascimento=datetime.date(1910, 4, 2), estado='CE', data_cadastro=datetime.date(2023, 2, 14), ipv4='172.225.78.0', cor_favorita='Verde', profissao='Sargento', telefone='+55 (021) 3322 7063'),
#  Row(cpf='089.276.145-85', email='caua85@yahoo.com.br', senha='8V%T2eBfi(', data_de_nascimento=datetime.date(1939, 12, 30), estado='PE', data_cadastro=datetime.date(2023, 3, 11), ipv4='110.188.83.186', cor_favorita='Verde', profissao='Comissário De Bordo', telefone='84 6794 1208'),
#  Row(cpf='819.506.732-86', email='marcela40@gmail.com', senha='k+g(8Ki@sn', data_de_nascimento=datetime.date(2014, 12, 31), estado='TO', data_cadastro=datetime.date(2023, 2, 28), ipv4='91.159.82.213', cor_favorita='Ciano', profissao='Espeleologista', telefone='41 8190-4348'),
#  Row(cpf='932.567.014-34', email='caio40@hotmail.com', senha='2UQ2p)5q@Y', data_de_nascimento=datetime.date(1986, 1, 31), estado='GO', data_cadastro=datetime.date(2023, 1, 22), ipv4='112.23.224.126', cor_favorita='Azul', profissao='Flautista', telefone='+55 (081) 5756-7067'),
#  Row(cpf='189.462.350-98', email='onunes@hotmail.com', senha='pIKUqi2)!5', data_de_nascimento=datetime.date(1951, 5, 15), estado='PB', data_cadastro=datetime.date(2023, 1, 11), ipv4='198.91.114.111', cor_favorita='Laranja', profissao='Político', telefone='0800-590-6357'),
#  Row(cpf='874.092.613-31', email='bruno71@yahoo.com.br', senha='HF1FfNe5&H', data_de_nascimento=datetime.date(1946, 11, 25), estado='SP', data_cadastro=datetime.date(2023, 3, 3), ipv4='14.80.253.67', cor_favorita='Violeta', profissao='Confeiteiro', telefone='(084) 0687-3775'),
#  Row(cpf='279.430.816-50', email='gmartins@bol.com.br', senha='_d3VPWjvc2', data_de_nascimento=datetime.date(1941, 7, 24), estado='PB', data_cadastro=datetime.date(2023, 1, 27), ipv4='167.248.54.174', cor_favorita='Azul Escuro', profissao='Tecnólogo Em Processos Químicos', telefone='+55 21 0579-4147'),
#  Row(cpf='725.186.940-30', email='osouza@uol.com.br', senha='2zHY(zHl+2', data_de_nascimento=datetime.date(1941, 8, 25), estado='PI', data_cadastro=datetime.date(2023, 2, 9), ipv4='74.159.210.39', cor_favorita='Marrom', profissao='Ginasta Rítmica', telefone='21 6564-7892'),
#  Row(cpf='723.419.058-97', email='joana43@uol.com.br', senha='vk7R1o#zI!', data_de_nascimento=datetime.date(1936, 1, 31), estado='RR', data_cadastro=datetime.date(2023, 2, 7), ipv4='23.153.28.160', cor_favorita='Azul', profissao='Jogador De Futebol', telefone='0900 150 4170'),
#  Row(cpf='136.894.750-66', email='barrossarah@bol.com.br', senha='zm1eLH9t%o', data_de_nascimento=datetime.date(1975, 5, 21), estado='CE', data_cadastro=datetime.date(2023, 1, 11), ipv4='79.204.112.52', cor_favorita='Magenta', profissao='Auxiliar De Serviços Gerais', telefone='11 7350 7069'),
#  Row(cpf='172.586.340-53', email='santosthomas@yahoo.com.br', senha='!5WU2Rt1N0', data_de_nascimento=datetime.date(1947, 8, 28), estado='PA', data_cadastro=datetime.date(2023, 1, 31), ipv4='43.247.165.243', cor_favorita='Preto', profissao='Síndico', telefone='0900-722-2268'),
#  Row(cpf='943.185.762-64', email='melissa97@bol.com.br', senha='MBlZ9BOwp(', data_de_nascimento=datetime.date(1953, 6, 9), estado='PE', data_cadastro=datetime.date(2023, 1, 16), ipv4='97.254.23.196', cor_favorita='Azul', profissao='Físico', telefone='31 6169-0705'),
#  Row(cpf='465.092.837-00', email='stellacastro@uol.com.br', senha='t@3Fyqzr&#', data_de_nascimento=datetime.date(2005, 12, 3), estado='PR', data_cadastro=datetime.date(2023, 1, 4), ipv4='105.93.60.18', cor_favorita='Laranja', profissao='Piloto Automobilístico', telefone='0500 746 4091'),
#  Row(cpf='637.084.291-50', email='lauraduarte@gmail.com', senha='o$w3eqIo93', data_de_nascimento=datetime.date(1912, 9, 27), estado='MT', data_cadastro=datetime.date(2023, 3, 8), ipv4='26.40.106.52', cor_favorita='Roxo', profissao='Moldureiro', telefone='+55 51 6658 8118'),
#  Row(cpf='423.051.986-98', email='pietra51@yahoo.com.br', senha='Z@p!1ReS2Y', data_de_nascimento=datetime.date(1979, 2, 12), estado='DF', data_cadastro=datetime.date(2023, 3, 8), ipv4='3.255.165.251', cor_favorita='Verde Escuro', profissao='Engenheiro De Transportes', telefone='0300-116-8911'),
#  Row(cpf='578.604.193-00', email='davi-luiz43@bol.com.br', senha='2h#0jBjjff', data_de_nascimento=datetime.date(1969, 10, 9), estado='MA', data_cadastro=datetime.date(2023, 3, 13), ipv4='52.66.96.237', cor_favorita='Azul Escuro', profissao='Engenheiro De Energia', telefone='+55 41 3890 7536'),
#  Row(cpf='182.465.039-60', email='thiagoribeiro@uol.com.br', senha='_6YG$puD!u', data_de_nascimento=datetime.date(1995, 1, 19), estado='TO', data_cadastro=datetime.date(2023, 1, 14), ipv4='155.152.181.214', cor_favorita='Preto', profissao='Gestor Público', telefone='71 6300 0649'),
#  Row(cpf='207.185.936-77', email='isabellypires@yahoo.com.br', senha='^4#BIX@f96', data_de_nascimento=datetime.date(1971, 11, 27), estado='BA', data_cadastro=datetime.date(2023, 2, 11), ipv4='93.238.65.111', cor_favorita='Verde', profissao='Alfaiate', telefone='+55 61 1689-4767'),
#  Row(cpf='736.590.214-07', email='ana-sophia70@hotmail.com', senha='wzKlkY_m^1', data_de_nascimento=datetime.date(1978, 7, 22), estado='CE', data_cadastro=datetime.date(2023, 1, 21), ipv4='107.91.53.244', cor_favorita='Magenta', profissao='Capataz', telefone='+55 84 2872 4942'),
#  Row(cpf='947.615.238-91', email='yda-paz@bol.com.br', senha='wVmsBsEn@4', data_de_nascimento=datetime.date(1950, 11, 29), estado='SC', data_cadastro=datetime.date(2023, 2, 13), ipv4='100.172.217.120', cor_favorita='Magenta', profissao='Surfista', telefone='+55 41 6990 8024'),
#  Row(cpf='941.703.825-79', email='jda-costa@uol.com.br', senha='T@1Mnixe)+', data_de_nascimento=datetime.date(1911, 8, 3), estado='ES', data_cadastro=datetime.date(2023, 3, 10), ipv4='21.189.216.91', cor_favorita='Preto', profissao='Clarinetista', telefone='+55 21 4333 7897'),
#  Row(cpf='687.352.104-35', email='eda-costa@gmail.com', senha='*2Fa+bVkz3', data_de_nascimento=datetime.date(1931, 5, 23), estado='AM', data_cadastro=datetime.date(2023, 2, 11), ipv4='210.18.197.187', cor_favorita='Laranja', profissao='Montador De Negativos', telefone='+55 (084) 1156-7824'),
#  Row(cpf='856.320.419-05', email='scampos@bol.com.br', senha='@*rkAfImD1', data_de_nascimento=datetime.date(1997, 6, 8), estado='PE', data_cadastro=datetime.date(2023, 1, 31), ipv4='175.72.45.212', cor_favorita='Cinza', profissao='Designer De Interiores', telefone='+55 11 5760 0473'),
#  Row(cpf='729.185.360-59', email='vsilveira@yahoo.com.br', senha='cq8@kILnf_', data_de_nascimento=datetime.date(2019, 10, 28), estado='RS', data_cadastro=datetime.date(2023, 3, 3), ipv4='58.220.108.182', cor_favorita='Verde Escuro', profissao='Químico Farmacêutico', telefone='+55 (041) 9143 7231'),
#  Row(cpf='518.490.623-15', email='ana08@yahoo.com.br', senha='Dg9epjTlI)', data_de_nascimento=datetime.date(2003, 10, 20), estado='PB', data_cadastro=datetime.date(2023, 2, 2), ipv4='104.37.135.232', cor_favorita='Marrom', profissao='Skatista', telefone='+55 (021) 4307 4419'),
#  Row(cpf='076.124.398-40', email='aragaoaugusto@hotmail.com', senha='Tou6EjY6+I', data_de_nascimento=datetime.date(1987, 7, 10), estado='RS', data_cadastro=datetime.date(2023, 3, 9), ipv4='202.143.70.72', cor_favorita='Azul', profissao='Tosador', telefone='+55 71 5928-0948'),
#  Row(cpf='891.603.475-20', email='araujoelisa@ig.com.br', senha='7I&8CYyU5Y', data_de_nascimento=datetime.date(1958, 1, 3), estado='MS', data_cadastro=datetime.date(2023, 2, 17), ipv4='39.216.170.1', cor_favorita='Verde Escuro', profissao='Jogador De Futebol', telefone='71 8049-1602'),
#  Row(cpf='943.516.028-05', email='davidas-neves@yahoo.com.br', senha='%G3O8WBl%q', data_de_nascimento=datetime.date(1944, 4, 21), estado='PE', data_cadastro=datetime.date(2023, 2, 1), ipv4='166.78.158.170', cor_favorita='Cinza', profissao='Sociólogo', telefone='61 8308 7207'),
#  Row(cpf='325.047.689-74', email='emanuella26@gmail.com', senha='r7pQOb%l)O', data_de_nascimento=datetime.date(1944, 5, 13), estado='RJ', data_cadastro=datetime.date(2023, 2, 19), ipv4='157.219.232.212', cor_favorita='Roxo', profissao='Kite-Surfer', telefone='(041) 2315 8540'),
#  Row(cpf='517.264.980-85', email='ana-sophiajesus@bol.com.br', senha='w9jTwVpj_r', data_de_nascimento=datetime.date(2018, 1, 4), estado='GO', data_cadastro=datetime.date(2023, 1, 10), ipv4='163.253.182.70', cor_favorita='Amarelo', profissao='Jogador De Boliche', telefone='0800-940-3789'),
#  Row(cpf='486.270.951-67', email='thomasmartins@gmail.com', senha='2pH9Ec@s8_', data_de_nascimento=datetime.date(2016, 5, 15), estado='ES', data_cadastro=datetime.date(2023, 1, 9), ipv4='159.2.213.99', cor_favorita='Preto', profissao='Guarda Ou Policial Rodoviário', telefone='84 6845-3718'),
#  Row(cpf='184.679.502-85', email='pcastro@bol.com.br', senha='@43TYc!n(Z', data_de_nascimento=datetime.date(1991, 7, 31), estado='TO', data_cadastro=datetime.date(2023, 1, 25), ipv4='90.180.84.16', cor_favorita='Verde Claro', profissao='Meteorologista', telefone='+55 51 8507 1297'),
#  Row(cpf='576.243.180-08', email='leandrocorreia@uol.com.br', senha='!7KwaZh#nG', data_de_nascimento=datetime.date(1986, 1, 28), estado='RO', data_cadastro=datetime.date(2023, 2, 28), ipv4='197.111.235.83', cor_favorita='Laranja', profissao='Intérprete', telefone='61 5120 5126'),
#  Row(cpf='796.805.213-03', email='samuelfernandes@yahoo.com.br', senha='h&48Cv73ml', data_de_nascimento=datetime.date(1961, 8, 23), estado='DF', data_cadastro=datetime.date(2023, 1, 11), ipv4='183.76.213.133', cor_favorita='Azul', profissao='Agricultor', telefone='+55 71 2448 9698'),
#  Row(cpf='694.150.378-57', email='isaacda-rocha@uol.com.br', senha='qhlH2PTZ(1', data_de_nascimento=datetime.date(1982, 11, 30), estado='SE', data_cadastro=datetime.date(2023, 3, 9), ipv4='146.26.96.21', cor_favorita='Roxo', profissao='Engenheiro Acústico', telefone='+55 11 3248-3043'),
#  Row(cpf='153.760.894-01', email='cfarias@bol.com.br', senha='%^5YHpmquv', data_de_nascimento=datetime.date(1995, 2, 16), estado='MA', data_cadastro=datetime.date(2023, 2, 20), ipv4='208.253.31.50', cor_favorita='Azul Escuro', profissao='Procurador De Justiça', telefone='0900-961-9602'),
#  Row(cpf='150.973.284-50', email='nataliapereira@hotmail.com', senha='$Ok4Vht#w6', data_de_nascimento=datetime.date(1970, 10, 8), estado='MS', data_cadastro=datetime.date(2023, 3, 3), ipv4='134.119.72.209', cor_favorita='Cinza', profissao='Engenheiro Físico', telefone='21 5422 9784'),
#  Row(cpf='482.713.059-05', email='biancasilveira@uol.com.br', senha='OLyPf6U7*2', data_de_nascimento=datetime.date(1990, 3, 16), estado='PE', data_cadastro=datetime.date(2023, 1, 5), ipv4='168.182.87.73', cor_favorita='Violeta', profissao='Técnico De Gesso', telefone='+55 (021) 0118-1450'),
#  Row(cpf='731.642.895-37', email='rochamarcelo@uol.com.br', senha='KlY(0KvuY&', data_de_nascimento=datetime.date(1991, 11, 29), estado='DF', data_cadastro=datetime.date(2023, 3, 8), ipv4='158.243.21.144', cor_favorita='Laranja', profissao='Marechal', telefone='+55 (051) 2985 2625'),
#  Row(cpf='965.134.708-20', email='apires@bol.com.br', senha='_3Wg*UTZPK', data_de_nascimento=datetime.date(1931, 6, 27), estado='CE', data_cadastro=datetime.date(2023, 3, 12), ipv4='171.143.246.230', cor_favorita='Cinza', profissao='Analista De Sistemas', telefone='71 1719-4863'),
#  Row(cpf='495.068.172-94', email='alana94@bol.com.br', senha='IfV2bMYl(*', data_de_nascimento=datetime.date(1930, 6, 26), estado='ES', data_cadastro=datetime.date(2023, 3, 4), ipv4='32.46.82.32', cor_favorita='Marrom', profissao='Catador De Material Reciclável', telefone='11 7683-1500'),
#  Row(cpf='026.358.719-30', email='alexiasilva@yahoo.com.br', senha='#aMFx)3wI1', data_de_nascimento=datetime.date(1940, 9, 13), estado='RO', data_cadastro=datetime.date(2023, 2, 22), ipv4='52.91.52.76', cor_favorita='Azul', profissao='Baixista', telefone='(061) 3231-7250'),
#  Row(cpf='490.372.518-97', email='castrocatarina@gmail.com', senha='8hQ)9EiVZP', data_de_nascimento=datetime.date(1983, 6, 10), estado='SP', data_cadastro=datetime.date(2023, 1, 21), ipv4='5.188.180.112', cor_favorita='Azul Escuro', profissao='Epidemiólogo', telefone='61 5994-2692'),
#  Row(cpf='162.047.598-76', email='stephany89@hotmail.com', senha='t%^1USz$DN', data_de_nascimento=datetime.date(1944, 6, 16), estado='PB', data_cadastro=datetime.date(2023, 2, 1), ipv4='68.193.32.227', cor_favorita='Magenta', profissao='Cartunista', telefone='(071) 3336 6068'),
#  Row(cpf='603.248.715-62', email='franciscoda-cunha@bol.com.br', senha='h+7L0$mjaA', data_de_nascimento=datetime.date(1992, 10, 8), estado='RR', data_cadastro=datetime.date(2023, 2, 4), ipv4='26.166.234.56', cor_favorita='Cinza', profissao='Regente', telefone='(071) 8308 3783'),
#  Row(cpf='360.785.294-47', email='araujoluna@bol.com.br', senha='_%HD@txu5W', data_de_nascimento=datetime.date(1939, 11, 9), estado='DF', data_cadastro=datetime.date(2023, 3, 7), ipv4='167.91.9.69', cor_favorita='Violeta', profissao='Piloto Automobilístico', telefone='+55 (051) 2876 0562'),
#  Row(cpf='784.306.921-69', email='correialorena@yahoo.com.br', senha='@qz9EZs@4L', data_de_nascimento=datetime.date(1916, 9, 24), estado='PA', data_cadastro=datetime.date(2023, 2, 3), ipv4='178.92.175.196', cor_favorita='Cinza', profissao='Artesão', telefone='+55 21 2582-4429'),
#  Row(cpf='137.964.520-43', email='natalia72@ig.com.br', senha='i71MdCj2*^', data_de_nascimento=datetime.date(1939, 6, 26), estado='MG', data_cadastro=datetime.date(2023, 2, 3), ipv4='141.28.225.40', cor_favorita='Branco', profissao='Espeleologista', telefone='(041) 8471 8007'),
#  Row(cpf='974.251.360-07', email='nda-luz@uol.com.br', senha='+cxrgNv2&3', data_de_nascimento=datetime.date(1948, 4, 15), estado='RS', data_cadastro=datetime.date(2023, 3, 1), ipv4='55.238.24.36', cor_favorita='Rosa', profissao='Navegador', telefone='+55 61 5935-8887'),
#  Row(cpf='216.058.974-85', email='bribeiro@yahoo.com.br', senha='7cb)4Jgt5*', data_de_nascimento=datetime.date(1912, 5, 23), estado='PE', data_cadastro=datetime.date(2023, 1, 15), ipv4='73.118.46.165', cor_favorita='Preto', profissao='Pianista', telefone='+55 (031) 2307-4369'),
#  Row(cpf='613.280.547-80', email='bsales@yahoo.com.br', senha='4vK(7DWr+%', data_de_nascimento=datetime.date(1937, 9, 8), estado='ES', data_cadastro=datetime.date(2023, 1, 15), ipv4='94.179.212.163', cor_favorita='Verde Escuro', profissao='Teólogo', telefone='(051) 8452-9589'),
#  Row(cpf='375.620.418-90', email='erickramos@yahoo.com.br', senha='98CHFvpz+n', data_de_nascimento=datetime.date(2001, 9, 5), estado='BA', data_cadastro=datetime.date(2023, 3, 4), ipv4='28.110.187.96', cor_favorita='Ciano', profissao='Cinegrafista', telefone='+55 81 7285-5406'),
#  Row(cpf='379.481.056-20', email='mferreira@bol.com.br', senha='0NM02iPx@%', data_de_nascimento=datetime.date(1989, 11, 11), estado='RS', data_cadastro=datetime.date(2023, 2, 21), ipv4='117.139.103.140', cor_favorita='Preto', profissao='Tabelião', telefone='+55 (011) 1220-1729'),
#  Row(cpf='903.152.764-52', email='oda-luz@hotmail.com', senha='h0YnAwro(8', data_de_nascimento=datetime.date(2000, 4, 19), estado='DF', data_cadastro=datetime.date(2023, 1, 1), ipv4='145.209.252.166', cor_favorita='Violeta', profissao='Ajudante De Produção', telefone='0300-066-6036'),
#  Row(cpf='562.479.831-82', email='rezendelarissa@hotmail.com', senha='!6KVzmqd7L', data_de_nascimento=datetime.date(1985, 8, 24), estado='RR', data_cadastro=datetime.date(2023, 2, 23), ipv4='146.16.47.6', cor_favorita='Azul Escuro', profissao='Capitão', telefone='+55 71 7296 7623'),
#  Row(cpf='812.634.097-50', email='da-luzmilena@uol.com.br', senha='@F6qBs@o0c', data_de_nascimento=datetime.date(1964, 10, 19), estado='CE', data_cadastro=datetime.date(2023, 1, 22), ipv4='110.190.89.145', cor_favorita='Preto', profissao='Dublador', telefone='84 8417 8230'),
#  Row(cpf='654.907.238-74', email='gomescamila@yahoo.com.br', senha='oq)IJs3)$3', data_de_nascimento=datetime.date(1992, 6, 24), estado='RS', data_cadastro=datetime.date(2023, 1, 7), ipv4='34.47.146.72', cor_favorita='Branco', profissao='Penhorista', telefone='+55 41 1887-9503'),
#  Row(cpf='278.193.650-21', email='ribeirobruna@uol.com.br', senha='C#8^fSjv9@', data_de_nascimento=datetime.date(1947, 1, 21), estado='DF', data_cadastro=datetime.date(2023, 3, 10), ipv4='129.48.249.40', cor_favorita='Violeta', profissao='Cambista', telefone='31 0075-7345'),
#  Row(cpf='162.945.087-11', email='mcampos@ig.com.br', senha='K1!W_Yah@j', data_de_nascimento=datetime.date(1951, 2, 18), estado='RN', data_cadastro=datetime.date(2023, 1, 28), ipv4='90.134.143.95', cor_favorita='Verde Claro', profissao='Podólogo', telefone='81 9385-7193'),
#  Row(cpf='581.603.942-33', email='rfarias@ig.com.br', senha='V2VON5cb!Z', data_de_nascimento=datetime.date(1965, 7, 3), estado='SE', data_cadastro=datetime.date(2023, 1, 28), ipv4='17.67.210.90', cor_favorita='Branco', profissao='Percursionista', telefone='+55 71 5211-5525'),
#  Row(cpf='382.475.016-35', email='lopesenzo@yahoo.com.br', senha=')4dExFybO5', data_de_nascimento=datetime.date(1961, 9, 16), estado='GO', data_cadastro=datetime.date(2023, 1, 4), ipv4='115.205.238.140', cor_favorita='Amarelo', profissao='Argumentista', telefone='+55 (021) 8133 3501'),
#  Row(cpf='918.067.435-66', email='nicolascorreia@bol.com.br', senha='teO4@CdO@_', data_de_nascimento=datetime.date(1930, 10, 1), estado='BA', data_cadastro=datetime.date(2023, 1, 29), ipv4='112.50.139.82', cor_favorita='Preto', profissao='Preparador De Máquinas', telefone='(011) 9663-2474'),
#  Row(cpf='964.852.031-33', email='dda-conceicao@uol.com.br', senha='I1XrDIZs@o', data_de_nascimento=datetime.date(1942, 2, 9), estado='MA', data_cadastro=datetime.date(2023, 2, 11), ipv4='20.217.23.173', cor_favorita='Amarelo', profissao='Mecânico', telefone='(084) 1826-5845'),
#  Row(cpf='765.430.982-10', email='gabrielcunha@bol.com.br', senha='*de30DhmcY', data_de_nascimento=datetime.date(2002, 5, 23), estado='RJ', data_cadastro=datetime.date(2023, 1, 19), ipv4='10.158.51.13', cor_favorita='Verde Escuro', profissao='Camelô', telefone='+55 (011) 6838 1339'),
#  Row(cpf='124.387.069-96', email='pdas-neves@yahoo.com.br', senha='3^T9ePTK6w', data_de_nascimento=datetime.date(1970, 11, 5), estado='GO', data_cadastro=datetime.date(2023, 2, 13), ipv4='15.193.25.3', cor_favorita='Azul Escuro', profissao='Agricultor', telefone='(071) 0735 9084'),
#  Row(cpf='916.872.450-02', email='renanmartins@bol.com.br', senha='&R0_tWXgAG', data_de_nascimento=datetime.date(2006, 6, 22), estado='GO', data_cadastro=datetime.date(2023, 3, 11), ipv4='126.156.144.168', cor_favorita='Verde Escuro', profissao='Profissional De Comércio Exterior', telefone='0800-822-9241'),
#  Row(cpf='748.591.320-41', email='nalves@yahoo.com.br', senha='$U0HLVZti5', data_de_nascimento=datetime.date(1931, 12, 14), estado='RS', data_cadastro=datetime.date(2023, 3, 1), ipv4='131.147.18.150', cor_favorita='Violeta', profissao='Escoteiro', telefone='21 2856 4753'),
#  Row(cpf='790.482.315-23', email='noaharagao@hotmail.com', senha='#i_LhbOX52', data_de_nascimento=datetime.date(1922, 3, 19), estado='MG', data_cadastro=datetime.date(2023, 1, 25), ipv4='170.188.237.119', cor_favorita='Preto', profissao='Empacotador', telefone='+55 (031) 9156-3903'),
#  Row(cpf='912.684.357-91', email='diasjoao-pedro@yahoo.com.br', senha='ul4MAuou_k', data_de_nascimento=datetime.date(1940, 2, 2), estado='AM', data_cadastro=datetime.date(2023, 2, 6), ipv4='22.105.98.7', cor_favorita='Verde', profissao='Geógrafo', telefone='71 1972 8856'),
#  Row(cpf='385.679.014-48', email='vitoriacosta@uol.com.br', senha='Rp9y4nGIf+', data_de_nascimento=datetime.date(1926, 12, 14), estado='AP', data_cadastro=datetime.date(2023, 3, 10), ipv4='14.28.119.157', cor_favorita='Verde', profissao='Carnavalesco', telefone='+55 51 8887 1107'),
#  Row(cpf='071.635.289-30', email='piresmariane@yahoo.com.br', senha='+HR9(&Wk+S', data_de_nascimento=datetime.date(1920, 5, 2), estado='MT', data_cadastro=datetime.date(2023, 2, 25), ipv4='114.81.36.196', cor_favorita='Laranja', profissao='Corretor Da Bolsa De Valores', telefone='+55 61 5375-9753'),
#  Row(cpf='408.613.759-39', email='ferreirabruno@yahoo.com.br', senha='5#J9KiN3ul', data_de_nascimento=datetime.date(1962, 12, 31), estado='RO', data_cadastro=datetime.date(2023, 2, 23), ipv4='38.211.232.142', cor_favorita='Preto', profissao='Açougueiro', telefone='+55 81 7511-2672'),
#  Row(cpf='903.582.167-02', email='kamillygoncalves@bol.com.br', senha=')3jm_maDO!', data_de_nascimento=datetime.date(1984, 11, 14), estado='MT', data_cadastro=datetime.date(2023, 1, 5), ipv4='72.49.143.216', cor_favorita='Rosa', profissao='Assessor De Imprensa', telefone='21 8976-6638'),
#  Row(cpf='298.516.304-89', email='joao-pedro43@yahoo.com.br', senha='Rh*pNaY+*2', data_de_nascimento=datetime.date(1975, 1, 22), estado='CE', data_cadastro=datetime.date(2023, 2, 20), ipv4='126.89.241.166', cor_favorita='Branco', profissao='Levantador De Peso', telefone='+55 11 4343-6740'),
#  Row(cpf='817.029.534-32', email='portoyuri@gmail.com', senha='fU7GnyXv&x', data_de_nascimento=datetime.date(2006, 3, 13), estado='DF', data_cadastro=datetime.date(2023, 1, 8), ipv4='29.59.19.242', cor_favorita='Rosa', profissao='Engenheiro Mecatrônico', telefone='84 1231 7635'),
#  Row(cpf='785.469.302-10', email='martinsbeatriz@uol.com.br', senha='tn0qTo9$&N', data_de_nascimento=datetime.date(1969, 9, 24), estado='PB', data_cadastro=datetime.date(2023, 1, 5), ipv4='123.135.60.13', cor_favorita='Verde Claro', profissao='Copeiro', telefone='71 0790-7505'),
#  Row(cpf='820.356.194-24', email='luiz-fernandomoraes@hotmail.com', senha='@59B3hAxps', data_de_nascimento=datetime.date(2023, 1, 20), estado='RS', data_cadastro=datetime.date(2023, 3, 5), ipv4='36.48.240.226', cor_favorita='Marrom', profissao='Radiooperador De Vôo', telefone='+55 (041) 8789-9421'),
#  Row(cpf='648.527.910-58', email='silveiraian@ig.com.br', senha='*d6Q*3GaxP', data_de_nascimento=datetime.date(1954, 11, 18), estado='SC', data_cadastro=datetime.date(2023, 2, 1), ipv4='171.25.39.151', cor_favorita='Rosa', profissao='Nutricionista', telefone='21 6961-9185'),
#  Row(cpf='704.391.285-79', email='alexia76@bol.com.br', senha='@8(aMEorP_', data_de_nascimento=datetime.date(1996, 1, 21), estado='MA', data_cadastro=datetime.date(2023, 2, 24), ipv4='108.191.88.153', cor_favorita='Verde Claro', profissao='Sacoleira', telefone='+55 (051) 1760 8904'),
# ...
#  Row(cpf='807.625.193-12', email='rochanatalia@bol.com.br', senha='8tmDQHJu+F', data_de_nascimento=datetime.date(2011, 7, 12), estado='AP', data_cadastro=datetime.date(2023, 1, 18), ipv4='105.149.223.70', cor_favorita='Preto', profissao='Fiscal', telefone='+55 (061) 5948-9739'),
#  Row(cpf='014.875.623-90', email='ericksilva@yahoo.com.br', senha='0oq^0fDnCY', data_de_nascimento=datetime.date(1929, 3, 23), estado='MS', data_cadastro=datetime.date(2023, 3, 9), ipv4='53.127.111.205', cor_favorita='Marrom', profissao='Violonista', telefone='(021) 2115-4123'),
#  Row(cpf='147.205.986-76', email='da-costacaue@uol.com.br', senha='%6WdeNdMw9', data_de_nascimento=datetime.date(1926, 6, 7), estado='AC', data_cadastro=datetime.date(2023, 3, 11), ipv4='167.31.42.184', cor_favorita='Magenta', profissao='Gerente De Banco', telefone='+55 (051) 3801-1396'),
#  Row(cpf='857.031.426-44', email='cardosoaugusto@bol.com.br', senha='y0pW*^n1_d', data_de_nascimento=datetime.date(2014, 8, 3), estado='DF', data_cadastro=datetime.date(2023, 2, 12), ipv4='121.29.109.125', cor_favorita='Verde Escuro', profissao='Produtor Editorial', telefone='+55 (011) 4368 9998'),
#  Row(cpf='431.805.279-60', email='gcaldeira@bol.com.br', senha='_VWMaKQa_5', data_de_nascimento=datetime.date(2000, 8, 20), estado='ES', data_cadastro=datetime.date(2023, 1, 14), ipv4='177.49.139.86', cor_favorita='Azul Escuro', profissao='Jogador De Golfe', telefone='+55 81 7459 7959'),
#  Row(cpf='149.753.680-48', email='erodrigues@ig.com.br', senha='0YF%kNrh(9', data_de_nascimento=datetime.date(1919, 10, 15), estado='PB', data_cadastro=datetime.date(2023, 3, 2), ipv4='115.33.167.191', cor_favorita='Marrom', profissao='Ortesista', telefone='+55 71 5333 8842'),
#  Row(cpf='821.305.764-35', email='thomas03@uol.com.br', senha=')$0xhQY2wp', data_de_nascimento=datetime.date(1921, 11, 26), estado='SE', data_cadastro=datetime.date(2023, 1, 17), ipv4='132.149.69.174', cor_favorita='Azul', profissao='Ilustrador', telefone='31 0356-9561'),
#  Row(cpf='682.917.405-85', email='tda-rocha@bol.com.br', senha='b8*@6JHbT6', data_de_nascimento=datetime.date(2013, 3, 17), estado='AL', data_cadastro=datetime.date(2023, 1, 26), ipv4='28.235.191.252', cor_favorita='Verde', profissao='Odontologista Legal', telefone='+55 51 8612 6915'),
#  Row(cpf='938.254.671-55', email='igor19@yahoo.com.br', senha='#BrN0yvK5y', data_de_nascimento=datetime.date(1937, 1, 25), estado='SC', data_cadastro=datetime.date(2023, 1, 3), ipv4='12.142.104.17', cor_favorita='Laranja', profissao='Cobaia Médica', telefone='84 2389 9194'),
#  Row(cpf='237.941.068-22', email='rezendealicia@uol.com.br', senha='9$89bxHbl^', data_de_nascimento=datetime.date(1924, 2, 18), estado='CE', data_cadastro=datetime.date(2023, 2, 8), ipv4='170.156.210.91', cor_favorita='Verde Escuro', profissao='Repórter', telefone='0900-878-5316'),
#  Row(cpf='243.198.570-97', email='lucas-gabriel69@bol.com.br', senha='SBU0%@Rpn$', data_de_nascimento=datetime.date(1973, 10, 15), estado='BA', data_cadastro=datetime.date(2023, 2, 9), ipv4='86.244.61.162', cor_favorita='Azul', profissao='Soldado', telefone='+55 71 8847-0003'),
#  Row(cpf='370.986.215-95', email='alexiacavalcanti@yahoo.com.br', senha='vXwc9HTp&6', data_de_nascimento=datetime.date(1947, 4, 14), estado='DF', data_cadastro=datetime.date(2023, 1, 6), ipv4='137.162.224.251', cor_favorita='Rosa', profissao='Engenheiro Agrônomo', telefone='(061) 9714-2240'),
#  Row(cpf='653.809.427-92', email='isabelfreitas@ig.com.br', senha='m61SAaOz_6', data_de_nascimento=datetime.date(1985, 10, 12), estado='SE', data_cadastro=datetime.date(2023, 1, 24), ipv4='7.77.160.38', cor_favorita='Rosa', profissao='Agente De Viagens', telefone='+55 51 8504 7135'),
#  Row(cpf='731.608.492-87', email='emelo@hotmail.com', senha='8$)7OqA!8x', data_de_nascimento=datetime.date(2012, 7, 30), estado='RO', data_cadastro=datetime.date(2023, 2, 7), ipv4='148.219.100.38', cor_favorita='Marrom', profissao='Epidemiólogo', telefone='31 5035 4964'),
#  Row(cpf='803.697.254-92', email='da-luzjoana@gmail.com', senha='*ubv^RIl+8', data_de_nascimento=datetime.date(1977, 3, 30), estado='AC', data_cadastro=datetime.date(2023, 1, 23), ipv4='204.226.56.149', cor_favorita='Marrom', profissao='Fisioterapeuta', telefone='(084) 9169-7053'),
#  Row(cpf='125.308.764-44', email='lopesrafaela@hotmail.com', senha='(hwWcPgLO8', data_de_nascimento=datetime.date(2021, 8, 16), estado='RR', data_cadastro=datetime.date(2023, 1, 1), ipv4='216.127.43.225', cor_favorita='Branco', profissao='Jogador De Tênis De Mesa', telefone='31 6370-9482'),
#  Row(cpf='258.973.061-68', email='maria-fernandafreitas@gmail.com', senha='348!DPfl(2', data_de_nascimento=datetime.date(1914, 6, 22), estado='MT', data_cadastro=datetime.date(2023, 2, 15), ipv4='11.149.236.102', cor_favorita='Roxo', profissao='Coach', telefone='+55 (041) 0606 9899'),
#  Row(cpf='465.327.810-53', email='barbosarafael@yahoo.com.br', senha=')5p%PsjoX1', data_de_nascimento=datetime.date(1920, 11, 2), estado='SP', data_cadastro=datetime.date(2023, 2, 8), ipv4='163.88.147.210', cor_favorita='Amarelo', profissao='Florista', telefone='+55 (061) 9849-8108'),
#  Row(cpf='697.234.501-43', email='moreiralarissa@bol.com.br', senha='ssL9JHpul_', data_de_nascimento=datetime.date(1909, 9, 15), estado='AL', data_cadastro=datetime.date(2023, 2, 20), ipv4='222.129.73.250', cor_favorita='Marrom', profissao='Notário', telefone='+55 (071) 9903-3825'),
#  Row(cpf='918.463.750-10', email='da-luzdiego@ig.com.br', senha='A(UU4H0C^u', data_de_nascimento=datetime.date(1925, 6, 13), estado='AP', data_cadastro=datetime.date(2023, 1, 7), ipv4='42.225.229.163', cor_favorita='Azul', profissao='Gari', telefone='+55 21 1570 7137'),
#  Row(cpf='417.206.359-43', email='gustavo-henrique17@ig.com.br', senha='t@9J#rQy+e', data_de_nascimento=datetime.date(2018, 8, 5), estado='GO', data_cadastro=datetime.date(2023, 1, 1), ipv4='164.92.218.202', cor_favorita='Laranja', profissao='Arquivista', telefone='+55 (051) 2597-2224'),
#  Row(cpf='486.352.719-55', email='mariada-paz@hotmail.com', senha='Z*4IkTXe&g', data_de_nascimento=datetime.date(1995, 12, 30), estado='PB', data_cadastro=datetime.date(2023, 2, 3), ipv4='208.91.107.226', cor_favorita='Roxo', profissao='Gestor Ambiental', telefone='(084) 6293 4846'),
#  Row(cpf='729.861.053-86', email='isaaccavalcanti@uol.com.br', senha='v@C!7CgY+h', data_de_nascimento=datetime.date(1910, 6, 26), estado='SE', data_cadastro=datetime.date(2023, 2, 1), ipv4='61.89.36.100', cor_favorita='Verde Escuro', profissao='Agrimensor', telefone='+55 51 1036 3588'),
#  Row(cpf='214.703.685-44', email='vda-rocha@bol.com.br', senha='8qO9TZBD1&', data_de_nascimento=datetime.date(2014, 6, 19), estado='PB', data_cadastro=datetime.date(2023, 3, 7), ipv4='211.177.249.228', cor_favorita='Verde Claro', profissao='Terapeuta Holístico', telefone='+55 31 2919 1689'),
#  Row(cpf='805.643.297-38', email='maria-fernandafarias@hotmail.com', senha='(6NDG+Ty8c', data_de_nascimento=datetime.date(2009, 10, 12), estado='RJ', data_cadastro=datetime.date(2023, 1, 31), ipv4='204.97.143.138', cor_favorita='Rosa', profissao='Geofísico', telefone='+55 31 4389 2589'),
#  Row(cpf='349.708.261-96', email='nataliamartins@gmail.com', senha='!yEMqAcb0r', data_de_nascimento=datetime.date(1975, 1, 24), estado='AP', data_cadastro=datetime.date(2023, 1, 25), ipv4='213.122.166.62', cor_favorita='Branco', profissao='Diretor De Produção', telefone='+55 (011) 6336-1837'),
#  Row(cpf='031.842.697-87', email='gustavo-henriqueda-mata@bol.com.br', senha='+%_+46Iky6', data_de_nascimento=datetime.date(2020, 3, 29), estado='CE', data_cadastro=datetime.date(2023, 2, 15), ipv4='158.28.191.200', cor_favorita='Cinza', profissao='Tosador', telefone='(021) 3396-5487'),
#  Row(cpf='309.482.175-88', email='duarteheloisa@gmail.com', senha='*_9^hDGjQp', data_de_nascimento=datetime.date(2013, 6, 30), estado='TO', data_cadastro=datetime.date(2023, 2, 3), ipv4='96.5.191.76', cor_favorita='Amarelo', profissao='Desenhista', telefone='+55 (031) 9135-8151'),
#  Row(cpf='452.961.783-19', email='jcastro@uol.com.br', senha='6X8BDmq0E#', data_de_nascimento=datetime.date(1917, 5, 27), estado='CE', data_cadastro=datetime.date(2023, 2, 28), ipv4='148.243.207.215', cor_favorita='Rosa', profissao='Técnico Em Óptica', telefone='(011) 1677 4555'),
#  Row(cpf='472.936.801-04', email='thomasda-cunha@hotmail.com', senha='$2S2rNJw)j', data_de_nascimento=datetime.date(1936, 12, 7), estado='PI', data_cadastro=datetime.date(2023, 2, 5), ipv4='102.12.173.236', cor_favorita='Rosa', profissao='Juiz Ou Árbitro De Futebol', telefone='(011) 9818 8891'),
#  Row(cpf='428.517.960-11', email='benjaminbarbosa@gmail.com', senha='Y(!61T4cRy', data_de_nascimento=datetime.date(1957, 3, 8), estado='RO', data_cadastro=datetime.date(2023, 1, 15), ipv4='51.4.197.81', cor_favorita='Ciano', profissao='Astrofísico', telefone='+55 21 3390-4604'),
#  Row(cpf='795.236.041-80', email='limaerick@bol.com.br', senha='&6*iiL@joZ', data_de_nascimento=datetime.date(2008, 5, 5), estado='GO', data_cadastro=datetime.date(2023, 2, 15), ipv4='165.252.44.179', cor_favorita='Preto', profissao='Fisiculturista', telefone='+55 (084) 3979 7255'),
#  Row(cpf='826.950.417-30', email='carolinanunes@bol.com.br', senha='USR4biWmt&', data_de_nascimento=datetime.date(1938, 5, 30), estado='MG', data_cadastro=datetime.date(2023, 2, 3), ipv4='18.115.31.171', cor_favorita='Verde Claro', profissao='Chaveiro', telefone='+55 (031) 1466-5070'),
#  Row(cpf='127.643.985-73', email='emoraes@ig.com.br', senha='!J6u!cSjPW', data_de_nascimento=datetime.date(1988, 9, 13), estado='AC', data_cadastro=datetime.date(2023, 1, 28), ipv4='18.170.136.154', cor_favorita='Preto', profissao='Quiropraxista', telefone='+55 81 0646 7649'),
#  Row(cpf='361.805.429-70', email='emanuellaalmeida@ig.com.br', senha='Xee7FC*gT)', data_de_nascimento=datetime.date(2016, 4, 12), estado='SE', data_cadastro=datetime.date(2023, 1, 23), ipv4='89.172.33.243', cor_favorita='Branco', profissao='Administrador Público', telefone='81 2604-7365'),
#  Row(cpf='054.187.692-94', email='qsouza@uol.com.br', senha='W6sT$wQ1&9', data_de_nascimento=datetime.date(1908, 2, 24), estado='MA', data_cadastro=datetime.date(2023, 1, 11), ipv4='101.210.210.106', cor_favorita='Cinza', profissao='Professor', telefone='+55 (011) 9183 8269'),
#  Row(cpf='683.970.451-39', email='lucaspinto@yahoo.com.br', senha='1(TH8MUd_s', data_de_nascimento=datetime.date(1914, 5, 14), estado='RN', data_cadastro=datetime.date(2023, 2, 3), ipv4='192.73.71.87', cor_favorita='Rosa', profissao='Jóquei', telefone='31 7712-9145'),
#  Row(cpf='789.345.201-32', email='lucas88@ig.com.br', senha='Em!Dd2Hrby', data_de_nascimento=datetime.date(1930, 12, 10), estado='CE', data_cadastro=datetime.date(2023, 1, 19), ipv4='94.132.46.106', cor_favorita='Verde Escuro', profissao='Escoteiro', telefone='21 9121 4456'),
#  Row(cpf='364.981.720-96', email='theo69@yahoo.com.br', senha='HF)e^7IeGs', data_de_nascimento=datetime.date(1953, 9, 7), estado='MG', data_cadastro=datetime.date(2023, 1, 17), ipv4='45.56.81.82', cor_favorita='Preto', profissao='Prático', telefone='+55 (061) 7322 9517'),
#  Row(cpf='106.237.948-96', email='joao-vitormendes@ig.com.br', senha='@b8k2IVxWe', data_de_nascimento=datetime.date(1965, 4, 23), estado='RJ', data_cadastro=datetime.date(2023, 1, 8), ipv4='98.5.122.221', cor_favorita='Azul', profissao='Designer De Produto Ou Desenhista Industrial', telefone='+55 (021) 5816-0977'),
#  Row(cpf='801.692.745-94', email='joaquimmoraes@hotmail.com', senha='@46U4STa*S', data_de_nascimento=datetime.date(1925, 2, 19), estado='MS', data_cadastro=datetime.date(2023, 2, 14), ipv4='46.88.64.66', cor_favorita='Cinza', profissao='Radiooperador De Vôo', telefone='+55 (084) 6440-8009'),
#  Row(cpf='714.695.023-99', email='limaguilherme@gmail.com', senha='&p9NLZwe04', data_de_nascimento=datetime.date(1984, 1, 1), estado='TO', data_cadastro=datetime.date(2023, 1, 6), ipv4='106.243.24.25', cor_favorita='Marrom', profissao='Antropólogo', telefone='+55 (061) 9921 7757'),
#  Row(cpf='520.847.639-83', email='joaquimvieira@yahoo.com.br', senha='^Ls6UVjPC9', data_de_nascimento=datetime.date(2006, 5, 17), estado='AL', data_cadastro=datetime.date(2023, 1, 18), ipv4='180.218.131.59', cor_favorita='Verde Escuro', profissao='Engenheiro Aeronáutico', telefone='+55 (071) 1896-1075'),
#  Row(cpf='173.948.052-04', email='da-motalevi@uol.com.br', senha='+2NrHt^riW', data_de_nascimento=datetime.date(1941, 3, 31), estado='RR', data_cadastro=datetime.date(2023, 2, 16), ipv4='105.125.90.30', cor_favorita='Roxo', profissao='Promotor De Eventos', telefone='81 7920 9432'),
#  Row(cpf='824.165.730-71', email='alveserick@hotmail.com', senha='$n(MXjqh!0', data_de_nascimento=datetime.date(1907, 5, 26), estado='RO', data_cadastro=datetime.date(2023, 2, 19), ipv4='87.31.168.117', cor_favorita='Rosa', profissao='Biotecnólogo', telefone='(084) 9069 8763'),
#  Row(cpf='627.985.130-30', email='fariasgiovanna@gmail.com', senha='#8SVuy(PpB', data_de_nascimento=datetime.date(1921, 9, 28), estado='CE', data_cadastro=datetime.date(2023, 2, 26), ipv4='193.152.66.111', cor_favorita='Azul Escuro', profissao='Jogador De Bocha', telefone='0800-357-0775'),
#  Row(cpf='573.809.621-59', email='novaesana-julia@hotmail.com', senha='DfbV7W1^&4', data_de_nascimento=datetime.date(1972, 8, 15), estado='AC', data_cadastro=datetime.date(2023, 1, 4), ipv4='208.213.179.222', cor_favorita='Laranja', profissao='Tecelão', telefone='+55 (031) 6916 9086'),
#  Row(cpf='603.572.914-25', email='da-cruzgabriel@yahoo.com.br', senha='AVQlx^ft&9', data_de_nascimento=datetime.date(1910, 1, 12), estado='MG', data_cadastro=datetime.date(2023, 1, 2), ipv4='82.128.87.137', cor_favorita='Roxo', profissao='Técnico Em Edificações', telefone='(041) 9003 3229'),
#  Row(cpf='326.584.710-17', email='rodrigueselisa@ig.com.br', senha='*SlImT*s37', data_de_nascimento=datetime.date(1960, 2, 22), estado='SE', data_cadastro=datetime.date(2023, 2, 19), ipv4='40.26.20.124', cor_favorita='Verde', profissao='Cobrador De Ônibus', telefone='+55 (021) 0873 6829'),
#  Row(cpf='305.874.126-07', email='kevindias@bol.com.br', senha='8#3T4RWl)L', data_de_nascimento=datetime.date(1967, 7, 31), estado='PI', data_cadastro=datetime.date(2023, 2, 16), ipv4='147.123.154.195', cor_favorita='Roxo', profissao='Contra Regra', telefone='(081) 1872-2680'),
#  Row(cpf='835.012.476-80', email='voliveira@gmail.com', senha='i0(xBcbt_3', data_de_nascimento=datetime.date(1974, 10, 5), estado='AM', data_cadastro=datetime.date(2023, 2, 25), ipv4='221.115.206.51', cor_favorita='Branco', profissao='Profissional De Marketing', telefone='+55 (051) 0056 7866'),
#  Row(cpf='073.128.546-80', email='nicolas11@hotmail.com', senha='hp%24OQsr(', data_de_nascimento=datetime.date(1913, 4, 5), estado='AL', data_cadastro=datetime.date(2023, 2, 12), ipv4='132.202.220.34', cor_favorita='Verde Claro', profissao='Ortodontista', telefone='(031) 3563 5055'),
#  Row(cpf='841.950.263-42', email='francisco14@bol.com.br', senha='6^02PPwbKM', data_de_nascimento=datetime.date(1928, 7, 1), estado='ES', data_cadastro=datetime.date(2023, 1, 2), ipv4='71.49.101.55', cor_favorita='Azul', profissao='Tecnólogo Em Esporte E Lazer', telefone='+55 (061) 0639 3574'),
#  Row(cpf='175.682.043-08', email='barbara51@hotmail.com', senha='E5B6wYv8!i', data_de_nascimento=datetime.date(1945, 8, 21), estado='AM', data_cadastro=datetime.date(2023, 1, 9), ipv4='141.223.84.73', cor_favorita='Violeta', profissao='Musicoterapeuta', telefone='(051) 6399-9536'),
#  Row(cpf='570.263.819-03', email='imendes@yahoo.com.br', senha='^17tb#Fym_', data_de_nascimento=datetime.date(1929, 5, 18), estado='AL', data_cadastro=datetime.date(2023, 1, 16), ipv4='55.128.117.22', cor_favorita='Rosa', profissao='Pastilheiro', telefone='81 0564-6409'),
#  Row(cpf='651.278.304-26', email='erick64@uol.com.br', senha='VM9B65Ebc+', data_de_nascimento=datetime.date(1973, 1, 17), estado='BA', data_cadastro=datetime.date(2023, 2, 9), ipv4='62.164.220.163', cor_favorita='Azul Escuro', profissao='Implantodontista', telefone='(011) 4344 1564')]

# %%
pd.DataFrame(df.collect(), columns=df.columns)
# Out:
#                 cpf                     email       senha data_de_nascimento  \
# 0    981.507.362-12   pedro-lucas53@gmail.com  +7^7E%xFBc         2006-12-18
# 1    493.705.168-75  rezendeisaac@hotmail.com  _O_2GRnGOe         1992-06-17
# 2    398.471.625-73    felipepires@uol.com.br  *Aw5EOAvy9         1921-11-11
# 3    092.618.354-06   stellamoraes@bol.com.br  mw0AWYAs#s         2021-06-01
# 4    509.427.136-99       wcarvalho@ig.com.br  pGD%!2Pq5X         1969-10-28
# ..              ...                       ...         ...                ...
# 995  073.128.546-80     nicolas11@hotmail.com  hp%24OQsr(         1913-04-05
# 996  841.950.263-42    francisco14@bol.com.br  6^02PPwbKM         1928-07-01
# 997  175.682.043-08     barbara51@hotmail.com  E5B6wYv8!i         1945-08-21
# 998  570.263.819-03      imendes@yahoo.com.br  ^17tb#Fym_         1929-05-18
# 999  651.278.304-26        erick64@uol.com.br  VM9B65Ebc+         1973-01-17
#
#     estado data_cadastro            ipv4 cor_favorita  \
# 0       RR    2023-02-26  99.107.250.210         Roxo
# 1       GO    2023-02-16   197.11.26.213        Ciano
# 2       MG    2023-01-02    181.90.63.58         Azul
# 3       AC    2023-01-08   26.121.127.94       Marrom
# 4       AP    2023-02-14   76.184.52.163      Laranja
# ..     ...           ...             ...          ...
# 995     AL    2023-02-12  132.202.220.34  Verde Claro
# 996     ES    2023-01-02    71.49.101.55         Azul
# 997     AM    2023-01-09   141.223.84.73      Violeta
# 998     AL    2023-01-16   55.128.117.22         Rosa
# 999     BA    2023-02-09  62.164.220.163  Azul Escuro
#
#                         profissao             telefone
# 0                Jogador De Golfe         31 7785-4046
# 1     Atleta De Arremesso De Peso      (031) 0803-6753
# 2                  Papiloscopista         11 9674-0553
# 3                        Aeromoça  +55 (071) 3033 9177
# 4                   Fonoaudiólogo  +55 (071) 6272 2468
# ..                            ...                  ...
# 995                  Ortodontista      (031) 3563 5055
# 996  Tecnólogo Em Esporte E Lazer  +55 (061) 0639 3574
# 997               Musicoterapeuta      (051) 6399-9536
# 998                   Pastilheiro         81 0564-6409
# 999              Implantodontista      (011) 4344 1564
#
# [1000 rows x 10 columns]

# %%
pd
# Out:
# <module 'pandas' from 'd:\\AMBIENTE DE PROJETOS\\Anaconda_pySpark\\DATASETS\\.venv\\Lib\\site-packages\\pandas\\__init__.py'>

# %% [markdown]
# # Convertendo de Pandas para Spark

# %%
import pyspark.pandas as ps
